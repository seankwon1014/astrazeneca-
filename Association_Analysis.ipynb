# %% [markdown]
# # Import Modules

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import numpy as np
import time

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Data Load

# %%
def loading_data(temp):
    data = pd.DataFrame()
    data['safetyreportid'] = temp['safetyreportid']  # read 'safetyreportid' column
        
    patientdrug = temp['patient.drug'].apply(lambda x: x[0])  # read 'patientdrug' column
    data['openfda'] = patientdrug.apply(lambda x: x['openfda'] if 'openfda' in x.keys() else np.nan) # read 'openfda' line from dictionary
    data['generic_name'] = data['openfda'].apply(lambda x: x if type(x) != dict else (x['generic_name'] if 'generic_name' in x.keys() else np.nan)) # read 'generic_name' line from 'openfda' 
     
    stack = data.apply(lambda x: pd.Series(x['generic_name']), axis=1).stack().reset_index(level=1, drop=True) # split generic_name(list) to each different row
    stack.name = 'generic_name' # set the name
    data = data.drop('generic_name', axis=1) # drop generic_name column
    data = data.join(stack)
        
    data.drop('openfda', axis = 1, inplace=True)  # remove unnecessary columns
    return data

# %%
start = time.time() 

df = pd.DataFrame()
for i in range(1,134):
    a = 'data (' + str(i) + ').json'
    with open(a) as f:
        d = json.load(f) 
    result = json_normalize(d['results']) 
    temp = loading_data(result)
    df = pd.concat([df, temp], sort=False)

    
end = time.time()
(end - start)/60
# Out:
# 65.46581843694051

# %%
# df.to_csv('C:/AstraZeneca/market.csv')

# %%
# df = pd.read_csv('C:/AstraZeneca/market.csv', index_col=0)

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ### Missing Values

# %%
# Drop Missing Values
df.dropna(inplace = True)

# %% [markdown]
# ### String Manipulation

# %%
# Some data have 'comma' and 'AND' in  a generic_name column. Replace 'AND' to 'comma' to make it List.

df['generic_name'] = df['generic_name'].apply(lambda x: x.replace(", AND", ","))   
df['generic_name'] = df['generic_name'].apply(lambda x: x.replace(" AND", ","))

# %%
# Change string to List and split each element into different rows

df = pd.DataFrame(df['generic_name'].str.split(',').tolist(), index = df['safetyreportid']).stack().reset_index().drop('level_1', axis=1)

# Rename columns

df.columns = ['safetyreportid', 'generic_name']

# Remove space to make it clear (Some data have space while others don't have it in spite of the same generic name)

df['generic_name'] = df['generic_name'].apply(lambda x: x.replace(" ", ""))

# %% [markdown]
# # Pivot Table for Association Analysis

# %%
# Add vaue columns for aggregation

df['values'] = 1

# %%
# Count number of generic name by an ID

id_cnt = df['safetyreportid'].value_counts()
df.set_index('safetyreportid', inplace = True)

# Bring data having two or more generic names because data having only one generic name is meaningless in association
df = df[id_cnt > 1].reset_index()
# Out:
# C:\Users\Sihyun Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
# Group by to make it smaller

df = df.groupby(['safetyreportid','generic_name'])['values'].sum().reset_index()

# %%
# Pivot Table

table = pd.pivot_table(df, values='values', index=['safetyreportid'],
                    columns=['generic_name'], aggfunc=np.sum).fillna(0)

# %%
# Encode_units function to have only 0 or 1

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
table = table.applymap(encode_units)

# %%
# Final table
table.head(20)
# Out:
# generic_name       (COAGULATIONFACTORIX(RECOMBINANT)  (DAUNORUBICIN  \
# safetyreportid
# 4154661         0                                  0              0
# 5946536         0                                  0              0
# 6056280         0                                  0              0
# 6075952         0                                  0              0
# 6089495         0                                  0              0
# 6108212         0                                  0              0
# 6117053         0                                  0              0
# 6140824         0                                  0              0
# 6158684         0                                  0              0
# 6179494         0                                  0              0
# 6223895         0                                  0              0
# 6235935         0                                  0              0
# 6266604         0                                  0              0
# 6276658         0                                  0              0
# 6288573         0                                  0              0
# 6295783         0                                  0              0
# 6328668         0                                  0              0
# 6329174         0                                  0              0
# 6391021         0                                  0              0
# 6412995         0                                  0              0
#
# generic_name    (METHYLPHENIDATEHYDROCHLORIDE)  (SALINE)  .ALPHA.-TOCOPHEROL  \
# safetyreportid
# 4154661                                      0         0                   0
# 5946536                                      0         0                   0
# 6056280                                      0         0                   0
# 6075952                                      0         0                   0
# 6089495                                      0         0                   0
# 6108212                                      0         0                   0
# 6117053                                      0         0                   0
# 6140824                                      0         0                   0
# 6158684                                      0         0                   0
# 6179494                                      0         0                   0
# 6223895                                      0         0                   0
# 6235935                                      0         0                   0
# 6266604                                      0         0                   0
# 6276658                                      0         0                   0
# 6288573                                      0         0                   0
# 6295783                                      0         0                   0
# 6328668                                      0         0                   0
# 6329174                                      0         0                   0
# 6391021                                      0         0                   0
# 6412995                                      0         0                   0
#
# generic_name    .ALPHA.-TOCOPHEROLACETATE  .BETA.-CAROTENE  0.01%  \
# safetyreportid
# 4154661                                 0                0      0
# 5946536                                 0                0      0
# 6056280                                 0                0      0
# 6075952                                 0                0      0
# 6089495                                 0                0      0
# 6108212                                 0                0      0
# 6117053                                 0                0      0
# 6140824                                 0                0      0
# 6158684                                 0                0      0
# 6179494                                 0                0      0
# 6223895                                 0                0      0
# 6235935                                 0                0      0
# 6266604                                 0                0      0
# 6276658                                 0                0      0
# 6288573                                 0                0      0
# 6295783                                 0                0      0
# 6328668                                 0                0      0
# 6329174                                 0                0      0
# 6391021                                 0                0      0
# 6412995                                 0                0      0
#
# generic_name    0.02%/0.005%  ...  ZINCOXIDE  ZINCOXIDE8%  ZINCOXIDESUNSCREEN  \
# safetyreportid                ...
# 4154661                    0  ...          0            0                   0
# 5946536                    0  ...          0            0                   0
# 6056280                    0  ...          0            0                   0
# 6075952                    0  ...          0            0                   0
# 6089495                    0  ...          0            0                   0
# 6108212                    0  ...          0            0                   0
# 6117053                    0  ...          0            0                   0
# 6140824                    0  ...          0            0                   0
# 6158684                    0  ...          0            0                   0
# 6179494                    0  ...          0            0                   0
# 6223895                    0  ...          0            0                   0
# 6235935                    0  ...          0            0                   0
# 6266604                    0  ...          0            0                   0
# 6276658                    0  ...          0            0                   0
# 6288573                    0  ...          0            0                   0
# 6295783                    0  ...          0            0                   0
# 6328668                    0  ...          0            0                   0
# 6329174                    0  ...          0            0                   0
# 6391021                    0  ...          0            0                   0
# 6412995                    0  ...          0            0                   0
#
# generic_name    ZINCOXIDESUNSREEN  ZINCSULFATE  ZINCUMBROMATUM  \
# safetyreportid
# 4154661                         0            0               0
# 5946536                         0            0               0
# 6056280                         0            0               0
# 6075952                         0            0               0
# 6089495                         0            0               0
# 6108212                         0            0               0
# 6117053                         0            0               0
# 6140824                         0            0               0
# 6158684                         0            0               0
# 6179494                         0            0               0
# 6223895                         0            0               0
# 6235935                         0            0               0
# 6266604                         0            0               0
# 6276658                         0            0               0
# 6288573                         0            0               0
# 6295783                         0            0               0
# 6328668                         0            0               0
# 6329174                         0            0               0
# 6391021                         0            0               0
# 6412995                         0            0               0
#
# generic_name    ZINCUMMETALLICUM  ZINCVALERATEDIHYDRATE  ZIPRASIDONEHCL  \
# safetyreportid
# 4154661                        0                      0               0
# 5946536                        0                      0               0
# 6056280                        0                      0               0
# 6075952                        0                      0               0
# 6089495                        0                      0               0
# 6108212                        0                      0               0
# 6117053                        0                      0               0
# 6140824                        0                      0               0
# 6158684                        0                      0               0
# 6179494                        0                      0               0
# 6223895                        0                      0               0
# 6235935                        0                      0               0
# 6266604                        0                      0               0
# 6276658                        0                      0               0
# 6288573                        0                      0               0
# 6295783                        0                      0               0
# 6328668                        0                      0               0
# 6329174                        0                      0               0
# 6391021                        0                      0               0
# 6412995                        0                      0               0
#
# generic_name    ZIPRASIDONEHYDROCHLORIDE
# safetyreportid
# 4154661                                0
# 5946536                                0
# 6056280                                0
# 6075952                                0
# 6089495                                0
# 6108212                                0
# 6117053                                0
# 6140824                                0
# 6158684                                0
# 6179494                                0
# 6223895                                0
# 6235935                                0
# 6266604                                0
# 6276658                                0
# 6288573                                0
# 6295783                                0
# 6328668                                0
# 6329174                                0
# 6391021                                0
# 6412995                                0
#
# [20 rows x 1921 columns]

# %% [markdown]
# # Association Analysis

# %%
frequent_items = apriori(table, min_support=0.01, use_colnames=True)

# %%
# Count number of itemsets

frequent_items_list = frequent_items
frequent_items_list['itemsets'] = frequent_items_list['itemsets'].apply(lambda x: list(x))
frequent_items_list['cnt'] = frequent_items_list['itemsets'].apply(lambda x: len(x))

# %%
# Check the result having two or more itemsets sorted by a value of support

frequent_items_list[frequent_items_list['cnt'] > 1].sort_values('support', ascending = False)
# Out:
#       support                                           itemsets  cnt
# 91   0.069959                            [SACUBITRIL, VALSARTAN]    2
# 64   0.067445                          [AVOBENZONE, OCTOCRYLENE]    2
# 63   0.067383                           [OCTISALATE, AVOBENZONE]    2
# 89   0.067366                          [OCTISALATE, OCTOCRYLENE]    2
# 96   0.067366              [OCTISALATE, AVOBENZONE, OCTOCRYLENE]    3
# 87   0.049562                 [METHOTREXATESODIUM, METHOTREXATE]    2
# 78   0.040119        [ESOMEPRAZOLESODIUM, ESOMEPRAZOLEMAGNESIUM]    2
# 84   0.026827                        [IBUPROFEN, IBUPROFEN200MG]    2
# 82   0.026827                            [IBUPFROFEN, IBUPROFEN]    2
# 83   0.026827                       [IBUPFROFEN, IBUPROFEN200MG]    2
# 101  0.026827            [IBUPFROFEN, IBUPROFEN, IBUPROFEN200MG]    3
# 72   0.025647                [DEXAMETHASONE1.5MG, DEXAMETHASONE]    2
# 76   0.023887                    [DOCETAXELANHYDROUS, DOCETAXEL]    2
# 86   0.022162            [LEVETIRACETAM, LEVETIRACETAMINJECTION]    2
# 74   0.021725                [IBUPROFEN, DIPHENHYDRAMINECITRATE]    2
# 98   0.020925    [IBUPFROFEN, IBUPROFEN, DIPHENHYDRAMINECITRATE]    3
# 99   0.020925  [IBUPFROFEN, DIPHENHYDRAMINECITRATE, IBUPROFEN...    3
# 73   0.020925               [IBUPFROFEN, DIPHENHYDRAMINECITRATE]    2
# 75   0.020925           [IBUPROFEN200MG, DIPHENHYDRAMINECITRATE]    2
# 100  0.020925  [IBUPROFEN, DIPHENHYDRAMINECITRATE, IBUPROFEN2...    3
# 102  0.020925  [IBUPFROFEN, IBUPROFEN, DIPHENHYDRAMINECITRATE...    4
# 81   0.019075                        [PIBRENTASVIR, GLECAPREVIR]    2
# 61   0.018621                             [ASPIRIN, ASPIRIN81MG]    2
# 95   0.018604               [ASPIRIN, ASPIRIN81MG, ASPIRIN325MG]    3
# 62   0.018604                        [ASPIRIN81MG, ASPIRIN325MG]    2
# 60   0.018604                            [ASPIRIN, ASPIRIN325MG]    2
# 67   0.017491        [CIPROFLOXACINHYDROCHLORIDE, CIPROFLOXACIN]    2
# 94   0.017338                   [TACROLIMUSCAPSULES, TACROLIMUS]    2
# 88   0.017049                   [METOPROLOL, METOPROLOLTARTRATE]    2
# 92   0.016299              [SERTRALINEHYDROCHLORIDE, SERTRALINE]    2
# 79   0.013689        [VILANTEROLTRIFENATATE, FLUTICASONEFUROATE]    2
# 69   0.013456  [CIPROFLOXACINTABLETS, CIPROFLOXACINHYDROCHLOR...    2
# 68   0.013456              [CIPROFLOXACINTABLETS, CIPROFLOXACIN]    2
# 97   0.013456  [CIPROFLOXACINTABLETS, CIPROFLOXACINHYDROCHLOR...    3
# 80   0.012247                [FLUTICASONEPROPIONATE, SALMETEROL]    2
# 65   0.011912          [FORMOTEROLFUMARATEDIHYDRATE, BUDESONIDE]    2
# 71   0.011464                [CLOPIDOGRELBISULFATE, CLOPIDOGREL]    2
# 90   0.011220              [RANITIDINEHYDROCHLORIDE, RANITIDINE]    2
# 77   0.011214       [TENOFOVIRDISOPROXILFUMARATE, EMTRICITABINE]    2
# 66   0.011203                              [LEVODOPA, CARBIDOPA]    2
# 85   0.010868      [LAMOTRIGINECHEWABLEDISPERSIBLE, LAMOTRIGINE]    2
# 93   0.010516                    [SILDENAFIL, SILDENAFILCITRATE]    2
# 70   0.010023               [CITALOPRAM, CITALOPRAMHYDROBROMIDE]    2

# %%
# Association Rules to check Lift and Confidence

rules = association_rules(frequent_items, metric="lift", min_threshold=1)
rules.sort_values('lift', ascending = False).head(30)
# Out:
#                                           antecedents  \
# 21                           (CITALOPRAMHYDROBROMIDE)
# 20                                       (CITALOPRAM)
# 67                                (SILDENAFILCITRATE)
# 66                                       (SILDENAFIL)
# 50                   (LAMOTRIGINECHEWABLEDISPERSIBLE)
# 51                                      (LAMOTRIGINE)
# 12                                         (LEVODOPA)
# 13                                        (CARBIDOPA)
# 61                                       (RANITIDINE)
# 60                          (RANITIDINEHYDROCHLORIDE)
# 22                             (CLOPIDOGRELBISULFATE)
# 23                                      (CLOPIDOGREL)
# 11                                       (BUDESONIDE)
# 10                      (FORMOTEROLFUMARATEDIHYDRATE)
# 65                                       (SERTRALINE)
# 64                          (SERTRALINEHYDROCHLORIDE)
# 56                                       (METOPROLOL)
# 57                               (METOPROLOLTARTRATE)
# 68                               (TACROLIMUSCAPSULES)
# 69                                       (TACROLIMUS)
# 84        (CIPROFLOXACINHYDROCHLORIDE, CIPROFLOXACIN)
# 85                             (CIPROFLOXACINTABLETS)
# 83              (CIPROFLOXACINTABLETS, CIPROFLOXACIN)
# 18                             (CIPROFLOXACINTABLETS)
# 86                       (CIPROFLOXACINHYDROCHLORIDE)
# 19                       (CIPROFLOXACINHYDROCHLORIDE)
# 87                                    (CIPROFLOXACIN)
# 17                                    (CIPROFLOXACIN)
# 82  (CIPROFLOXACINTABLETS, CIPROFLOXACINHYDROCHLOR...
# 16                             (CIPROFLOXACINTABLETS)
#
#                                           consequents  antecedent support  \
# 21                                       (CITALOPRAM)            0.010023
# 20                           (CITALOPRAMHYDROBROMIDE)            0.010023
# 67                                       (SILDENAFIL)            0.010516
# 66                                (SILDENAFILCITRATE)            0.010516
# 50                                      (LAMOTRIGINE)            0.010868
# 51                   (LAMOTRIGINECHEWABLEDISPERSIBLE)            0.010868
# 12                                        (CARBIDOPA)            0.011203
# 13                                         (LEVODOPA)            0.011203
# 61                          (RANITIDINEHYDROCHLORIDE)            0.011243
# 60                                       (RANITIDINE)            0.011220
# 22                                      (CLOPIDOGREL)            0.011464
# 23                             (CLOPIDOGRELBISULFATE)            0.011464
# 11                      (FORMOTEROLFUMARATEDIHYDRATE)            0.011912
# 10                                       (BUDESONIDE)            0.014943
# 65                          (SERTRALINEHYDROCHLORIDE)            0.016299
# 64                                       (SERTRALINE)            0.016299
# 56                               (METOPROLOLTARTRATE)            0.017049
# 57                                       (METOPROLOL)            0.017049
# 68                                       (TACROLIMUS)            0.017338
# 69                               (TACROLIMUSCAPSULES)            0.017338
# 84                             (CIPROFLOXACINTABLETS)            0.017491
# 85        (CIPROFLOXACINHYDROCHLORIDE, CIPROFLOXACIN)            0.013456
# 83                       (CIPROFLOXACINHYDROCHLORIDE)            0.013456
# 18                       (CIPROFLOXACINHYDROCHLORIDE)            0.013456
# 86              (CIPROFLOXACINTABLETS, CIPROFLOXACIN)            0.017508
# 19                             (CIPROFLOXACINTABLETS)            0.017508
# 87  (CIPROFLOXACINTABLETS, CIPROFLOXACINHYDROCHLOR...            0.018042
# 17                             (CIPROFLOXACINTABLETS)            0.018042
# 82                                    (CIPROFLOXACIN)            0.013456
# 16                                    (CIPROFLOXACIN)            0.013456
#
#     consequent support   support  confidence       lift  leverage  conviction
# 21            0.010023  0.010023    1.000000  99.774632  0.009922         inf
# 20            0.010023  0.010023    1.000000  99.774632  0.009922         inf
# 67            0.010516  0.010516    1.000000  95.090124  0.010406         inf
# 66            0.010516  0.010516    1.000000  95.090124  0.010406         inf
# 50            0.010868  0.010868    1.000000  92.011488  0.010750         inf
# 51            0.010868  0.010868    1.000000  92.011488  0.010750         inf
# 12            0.011203  0.011203    1.000000  89.261398  0.011078         inf
# 13            0.011203  0.011203    1.000000  89.261398  0.011078         inf
# 61            0.011220  0.011220    0.997981  88.945987  0.011094  489.693257
# 60            0.011243  0.011220    1.000000  88.945987  0.011094         inf
# 22            0.011464  0.011464    1.000000  87.228713  0.011333         inf
# 23            0.011464  0.011464    1.000000  87.228713  0.011333         inf
# 11            0.014943  0.011912    1.000000  66.920623  0.011734         inf
# 10            0.011912  0.011912    0.797190  66.920623  0.011734    4.871975
# 65            0.016299  0.016299    1.000000  61.351671  0.016034         inf
# 64            0.016299  0.016299    1.000000  61.351671  0.016034         inf
# 56            0.017049  0.017049    1.000000  58.655792  0.016758         inf
# 57            0.017049  0.017049    1.000000  58.655792  0.016758         inf
# 68            0.017338  0.017338    1.000000  57.676596  0.017037         inf
# 69            0.017338  0.017338    1.000000  57.676596  0.017037         inf
# 84            0.013456  0.013456    0.769306  57.171317  0.013221    4.276411
# 85            0.017491  0.013456    1.000000  57.171317  0.013221         inf
# 83            0.017508  0.013456    1.000000  57.115721  0.013221         inf
# 18            0.017508  0.013456    1.000000  57.115721  0.013221         inf
# 86            0.013456  0.013456    0.768558  57.115721  0.013221    4.262588
# 19            0.013456  0.013456    0.768558  57.115721  0.013221    4.262588
# 87            0.013456  0.013456    0.745832  55.426864  0.013213    3.881464
# 17            0.013456  0.013456    0.745832  55.426864  0.013213    3.881464
# 82            0.018042  0.013456    1.000000  55.426864  0.013213         inf
# 16            0.018042  0.013456    1.000000  55.426864  0.013213         inf
